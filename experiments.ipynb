# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd

df = pd.read_csv('data/twitter-2013train-A.txt', sep='\t', header=-1, encoding='utf-8')
df.columns = ['id', 'label', 'tweet']
df["label"].apply(lambda x: x.strip())
df['label'] = df['label'].map({'positive': 1, 'negative': -1, 'neutral': 0})
df
# Out:
#                       id  label  \
# 0     264183816548130816      1
# 1     263405084770172928     -1
# 2     262163168678248449     -1
# 3     264249301910310912     -1
# 4     262682041215234048      0
# 5     264229576773861376      0
# 6     264105751826538497      1
# 7     264094586689953794     -1
# 8     212392538055778304      0
# 9     254941790757601280     -1
# 10    264169034155696130      0
# 11    263192091700654080      0
# 12    263398998675693568      1
# 13    263650552167157762      1
# 14    260200142420992000      0
# 15    264087629237202944      1
# 16    250692636330049538      0
# 17    263304719471087617      0
# 18    261954070938537985      1
# 19    260940907082293248      0
# 20    263956867787673600      1
# 21    263975113404342273      0
# 22    257343699460173824      1
# 23    264125591337463808     -1
# 24    262350309781823488     -1
# 25    264259830590603264     -1
# 26    257239661976625152      0
# 27    263868270006906880      0
# 28    264223934403211264      0
# 29    264041764460036096      1
# ...                  ...    ...
# 9654  108291720541777921     -1
# 9655  113758849688805376      0
# 9656  100198972324454400      1
# 9657  100575362601324544      1
# 9658  100575706446180354      1
# 9659  103220092308946944      1
# 9660  113365713082793984      1
# 9661  103232284173406208      1
# 9662  108247073098448896      0
# 9663  118167524167782401     -1
# 9664  103219394854912000      0
# 9665  104214530766274560      0
# 9666  108819813257842688      1
# 9667  104834373160935424     -1
# 9668  104017879887917056      1
# 9669  110180276801519616      1
# 9670  100665193335500800     -1
# 9671  103429907421466624      1
# 9672  106585520066404352     -1
# 9673  103217677996277760      1
# 9674  115268610204766209      1
# 9675  101812880151810048      0
# 9676  101060707134619648      1
# 9677  108232564933804032      1
# 9678  101450548439560192     -1
# 9679  103158179306807296      1
# 9680  103157324096618497      1
# 9681  100259220338905089      0
# 9682  104230318525001729      1
# 9683  100461938533863424     -1
#
#                                                   tweet
# 0     Gas by my house hit $3.39!!!! I\u2019m going t...
# 1     Theo Walcott is still shit\u002c watch Rafa an...
# 2     its not that I\u2019m a GSP fan\u002c i just h...
# 3     Iranian general says Israel\u2019s Iron Dome c...
# 4     Tehran\u002c Mon Amour: Obama Tried to Establi...
# 5     I sat through this whole movie just for Harry ...
# 6     with J Davlar 11th. Main rivals are team Polan...
# 7     Talking about ACT\u2019s && SAT\u2019s\u002c d...
# 8     Why is \""Happy Valentines Day\"" trending? It...
# 9     They may have a SuperBowl in Dallas\u002c but ...
# 10    Im bringing the monster load of candy tomorrow...
# 11    Apple software\u002c retail chiefs out in over...
# 12    @oluoch @victor_otti @kunjand I just watched i...
# 13    One of my best 8th graders Kory was excited af...
# 14    #Livewire Nadal confirmed for Mexican Open in ...
# 15    @MsSheLahY I didnt want to just pop up... but ...
# 16    @Alyoup005 @addicted2haley hmmmm  November is ...
# 17    #Iran US delisting MKO from global terrorists ...
# 18    @JackStirling serge is amazing... like hes act...
# 19    @HatersgonnHate_ @HAMlikeHussain @Ramythe3lite...
# 20    Good Morning Becky ! Thursday is going to be F...
# 21    Expect light-moderate rains over E. Visayas; C...
# 22    One ticket left for the @49ers game tomorrow! ...
# 23    AFC away fans on Saturday. All this stuff abou...
# 24    My Saturday night has consisted of me watching...
# 25    Why is it so hard to find the @TVGuideMagazine...
# 26    Game 1 of the NLCS and a rematch of the NFC Ch...
# 27    James hall LIVE in Indianapolis Dec.8th.. CHRI...
# 28    @TrevorJavier the heat game may cost alot more...
# 29    Never start working on your dreams and goals t...
# ...                                                 ...
# 9654  @Hopesolofans1 @hopesolo I hope my iPhone gets...
# 9655  brooke burke LLLINKKK Where can I find the dre...
# 9656  RT @SmileLikeMiley: There won't be just a Part...
# 9657  I think Sparks Fly music video will be worldwi...
# 9658  RT @PrettyMissSwift: I think Sparks Fly music ...
# 9659  After that, I'll start plugging mine and @joes...
# 9660  Man was that Jets and Cowboys game awesome or ...
# 9661                   MNF tonight! Let's go Sexy Rexy!
# 9662  Just checking in to see if I had a nightmare l...
# 9663  Lmao RT @HeatherNoel13: Curtis painter looks l...
# 9664  Monday Night Football #TeamTexans all day & to...
# 9665  @PierreGarcon85 come out and watch THOSE GUYS ...
# 9666  @PacificaPatch This Friday night, Terra Nova f...
# 9667  Hank Williams & whisky in an empty bar on a Fr...
# 9668  @kristiyamaguchi @markballas love that you 2 k...
# 9669  Huge thanks to those of you who came out to my...
# 9670  RT @Rach_RVX: #Londonriots is trending 3rd wor...
# 9671  I had a fun day on terra nova. Followed by a h...
# 9672  Today, we found out that Rob Henry tore his AC...
# 9673  Monday Night Football - Gary Neville did well ...
# 9674  Happy birthday, Hank Williams. In honor if the...
# 9675  can somebody please tell me why it says \""MNF...
# 9676  @andrewsikora The Tigers know it's a big game ...
# 9677  New cast of DWTS tba at 8pm tonight!! So excit...
# 9678  @stoney16 @JeffMossDSR I'd recommend just turn...
# 9679  RT @MNFootNg It's monday and Monday Night Foot...
# 9680  All I know is the road for that Lomardi start ...
# 9681  All Blue and White fam, we r meeting at Golden...
# 9682  @DariusButler28   Have a great game agaist Tam...
# 9683  I'm pisseeedddd that I missed Kid Cudi's show ...
#
# [9684 rows x 3 columns]

# %%
df["tweet"]
# Out:
# 0       Gas by my house hit $3.39!!!! I\u2019m going t...
# 1       Theo Walcott is still shit\u002c watch Rafa an...
# 2       its not that I\u2019m a GSP fan\u002c i just h...
# 3       Iranian general says Israel\u2019s Iron Dome c...
# 4       Tehran\u002c Mon Amour: Obama Tried to Establi...
# 5       I sat through this whole movie just for Harry ...
# 6       with J Davlar 11th. Main rivals are team Polan...
# 7       Talking about ACT\u2019s && SAT\u2019s\u002c d...
# 8       Why is \""Happy Valentines Day\"" trending? It...
# 9       They may have a SuperBowl in Dallas\u002c but ...
# 10      Im bringing the monster load of candy tomorrow...
# 11      Apple software\u002c retail chiefs out in over...
# 12      @oluoch @victor_otti @kunjand I just watched i...
# 13      One of my best 8th graders Kory was excited af...
# 14      #Livewire Nadal confirmed for Mexican Open in ...
# 15      @MsSheLahY I didnt want to just pop up... but ...
# 16      @Alyoup005 @addicted2haley hmmmm  November is ...
# 17      #Iran US delisting MKO from global terrorists ...
# 18      @JackStirling serge is amazing... like hes act...
# 19      @HatersgonnHate_ @HAMlikeHussain @Ramythe3lite...
# 20      Good Morning Becky ! Thursday is going to be F...
# 21      Expect light-moderate rains over E. Visayas; C...
# 22      One ticket left for the @49ers game tomorrow! ...
# 23      AFC away fans on Saturday. All this stuff abou...
# 24      My Saturday night has consisted of me watching...
# 25      Why is it so hard to find the @TVGuideMagazine...
# 26      Game 1 of the NLCS and a rematch of the NFC Ch...
# 27      James hall LIVE in Indianapolis Dec.8th.. CHRI...
# 28      @TrevorJavier the heat game may cost alot more...
# 29      Never start working on your dreams and goals t...
#                               ...
# 9654    @Hopesolofans1 @hopesolo I hope my iPhone gets...
# 9655    brooke burke LLLINKKK Where can I find the dre...
# 9656    RT @SmileLikeMiley: There won't be just a Part...
# 9657    I think Sparks Fly music video will be worldwi...
# 9658    RT @PrettyMissSwift: I think Sparks Fly music ...
# 9659    After that, I'll start plugging mine and @joes...
# 9660    Man was that Jets and Cowboys game awesome or ...
# 9661                     MNF tonight! Let's go Sexy Rexy!
# 9662    Just checking in to see if I had a nightmare l...
# 9663    Lmao RT @HeatherNoel13: Curtis painter looks l...
# 9664    Monday Night Football #TeamTexans all day & to...
# 9665    @PierreGarcon85 come out and watch THOSE GUYS ...
# 9666    @PacificaPatch This Friday night, Terra Nova f...
# 9667    Hank Williams & whisky in an empty bar on a Fr...
# 9668    @kristiyamaguchi @markballas love that you 2 k...
# 9669    Huge thanks to those of you who came out to my...
# 9670    RT @Rach_RVX: #Londonriots is trending 3rd wor...
# 9671    I had a fun day on terra nova. Followed by a h...
# 9672    Today, we found out that Rob Henry tore his AC...
# 9673    Monday Night Football - Gary Neville did well ...
# 9674    Happy birthday, Hank Williams. In honor if the...
# 9675    can somebody please tell me why it says \""MNF...
# 9676    @andrewsikora The Tigers know it's a big game ...
# 9677    New cast of DWTS tba at 8pm tonight!! So excit...
# 9678    @stoney16 @JeffMossDSR I'd recommend just turn...
# 9679    RT @MNFootNg It's monday and Monday Night Foot...
# 9680    All I know is the road for that Lomardi start ...
# 9681    All Blue and White fam, we r meeting at Golden...
# 9682    @DariusButler28   Have a great game agaist Tam...
# 9683    I'm pisseeedddd that I missed Kid Cudi's show ...
# Name: tweet, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk import tokenize

vectorizer_ngrams = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = "english", \
                             min_df = 3, \
                             ngram_range = (1,3), \
                             max_features = 10000)

vectorizer_chars = CountVectorizer(analyzer = "char",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = "english", \
                             min_df = 3, \
                             ngram_range = (2,5), \
                             max_features = 10000)

features_ngrams = vectorizer_ngrams.fit_transform(df["tweet"])
features_chars = vectorizer_chars.fit_transform(df["tweet"])

# %%
vocab_ngrams = vectorizer_ngrams.get_feature_names()
vocab_chars = vectorizer_chars.get_feature_names()
print len(vocab_ngrams)
print len(vocab_chars)

print vocab_ngrams[:100]
print vocab_chars[:100]
# print vocab_ngrams
# Out:
# 9888
# 10000
# [u'00', u'00 pm', u'00 u002c', u'000', u'00am', u'00pm', u'01', u'02', u'03', u'039', u'04', u'05', u'06', u'07', u'08', u'09', u'10', u'10 11', u'10 17', u'10 18', u'10 2011', u'10 27', u'10 30', u'10 30am', u'10 http', u'10 million', u'10 years', u'100', u'1000', u'101', u'105', u'106', u'106 park', u'10am', u'10pm', u'10pm itv2', u'10pm itv2 hurrraaaaah', u'10th', u'10th annual', u'10th birthday', u'10th grade', u'10th kansas', u'10th kansas nationwide', u'10th time', u'10th time season', u'11', u'11 02', u'11 12', u'11 30', u'11 http', u'11am', u'11pm', u'11pm iparty', u'11th', u'11th 2012', u'11th international', u'11th international cloud', u'12', u'12 u002c', u'120', u'12pm', u'12th', u'13', u'134', u'13th', u'13th desperation', u'13th desperation day', u'14', u'14 u002c', u'14th', u'15', u'15 2012', u'15 http', u'15 places', u'15 places 16', u'150', u'15pm', u'15th', u'15th august', u'15th august anthem', u'16', u'16 august', u'16 august isk', u'16 official', u'16 official uk', u'16 u002c', u'16 wednesday', u'16th', u'16th birthday', u'17', u'17th', u'18', u'18 http', u'18th', u'18th birthday', u'19', u'19 http', u'19 u002c', u'19th', u'19th http']
# [u' !', u' ! ', u' !!', u' #', u' #a', u' #b', u' #c', u' #d', u' #e', u' #f', u' #g', u' #h', u' #i', u' #l', u' #m', u' #n', u' #o', u' #p', u' #r', u' #s', u' #t', u' #w', u' $', u' &', u' & ', u' & t', u" '", u' (', u' (i', u' -', u' - ', u' - t', u' .', u' ..', u' ...', u' ... ', u' 1', u' 1 ', u' 10', u' 10 ', u' 10t', u' 10th', u' 11', u' 12', u' 13', u' 14', u' 15', u' 16', u' 17', u' 18', u' 19', u' 1s', u' 1st', u' 1st ', u' 2', u' 2 ', u' 20', u' 201', u' 2012', u' 21', u' 25', u' 26', u' 27', u' 28', u' 2n', u' 2nd', u' 2nd ', u' 3', u' 3 ', u' 30', u' 3r', u' 3rd', u' 3rd ', u' 4', u' 4 ', u' 4t', u' 4th', u' 4th ', u' 5', u' 5 ', u' 5t', u' 5th', u' 5th ', u' 6', u' 6t', u' 6th', u' 6th ', u' 7', u' 7 ', u' 7t', u' 7th', u' 7th ', u' 8', u' 8t', u' 8th', u' 9', u' :', u' :(', u' :)', u' :) ']

# %%
print features_ngrams[0], df["tweet"][0]
# Out:
#   (0, 1614)	1
#   (0, 8985)	1
#   (0, 7153)	1
#   (0, 3805)	1
#   (0, 1613)	1
#   (0, 3404)	1
#   (0, 8976)	1
#   (0, 281)	1
#   (0, 3813)	1
#   (0, 3907)	1
#   (0, 3316)	1 Gas by my house hit $3.39!!!! I\u2019m going to Chapel Hill on Sat. :)

# %%
print len(filter(lambda x: len(x.split()) == 1, vocab_ngrams))
print len(filter(lambda x: len(x.split()) == 2, vocab_ngrams))
print len(filter(lambda x: len(x.split()) == 3, vocab_ngrams))
print
print len(filter(lambda x: len(x) == 2, vocab_chars))
print len(filter(lambda x: len(x) == 3, vocab_chars))
print len(filter(lambda x: len(x) == 4, vocab_chars))
print len(filter(lambda x: len(x) == 5, vocab_chars))
# Out:
# 5194
# 3651
# 1043
#
# 799
# 2783
# 3768
# 2650

# %% [markdown]
# ## Model training

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import time

# %%
start = time.time()

clf = SVC(C=100, gamma=0.1)

cvm = KFold(5, shuffle=True, random_state=3)
s = cross_val_score(clf, features_ngrams, df["label"], cv=cvm, scoring='f1_macro')
print s.mean()

print "Time taken: {0}".format(time.time() - start)

# %%
start = time.time()

clf = SVC(C=100, gamma=0.1)

cvm = KFold(5, shuffle=True, random_state=3)
s = cross_val_score(clf, features_chars, df["label"], cv=cvm, scoring='f1_macro')
print s.mean()

print "Time taken: {0}".format(time.time() - start)
# Out:
# /usr/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-db9fe77a1fe8> in <module>()
#       5 cvm = KFold(5, shuffle=True, random_state=3)
#       6 s = cross_val_score(clf, features_chars, df["label"], cv=cvm, scoring='f1_macro')
# ----> 7 print ss.mean()
#       8
#       9 print "Time taken: {0}".format(time.time() - start)
#
# NameError: name 'ss' is not defined
